# %% [markdown]
# # Demo notbook TSP

# %% [markdown]
# First draft of demo notebook comparing classical solution to TSP (simulated annealing) with quantum algorithms quantum phase estimation QPE and quantum adiabatic annealing (QAA).

# %%
import matplotlib.pyplot as plt
from src.simulated_annealer import SimulatedAnnealer

# %%
sim = SimulatedAnnealer()

# %%
_ = sim.set_cities_coordinates(nr_of_cities=30)

# %%
_ = sim.solve_tsp(t_0=1, dt=0.0001)

# %%
#sim.plot_result(sim.current_order)

# %%
hist = sim.optimization_history

# %%
# %matplotlib widget
sim.plot_last_optimization_history()
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=19999, step=1000), Output()), _dom_classes=('w…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = sim.optimization_history[19000]
plt.plot(data[:,0], data[:,1])
